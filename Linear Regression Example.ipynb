# %%
##Simple Linear Regression Example

#Data Source:http://college.cengage.com/mathematics/brase/understandable_statistics/7e/students/datasets/slr/frames/slr06.html
#Data Description: Auto Insurance in Sweden

#X = number of claims
#Y = total payment for all the claims in thousands of Swedish Kronor

# %%
#Load Libraries

from sklearn.linear_model import LinearRegression
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Import Data

df = pd.read_csv('https://raw.githubusercontent.com/DataScienceClub777/DSC/master/auto_insurance_sweden.csv')

df.head()
# Out:
#      x      y
# 0  108  392.5
# 1   19   46.2
# 2   13   15.7
# 3  124  422.2
# 4   40  119.4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63 entries, 0 to 62
# Data columns (total 2 columns):
# x    63 non-null int64
# y    63 non-null float64
# dtypes: float64(1), int64(1)
# memory usage: 1.1 KB

# %%
#Split X and Y

x = df.iloc[:,0]
y = df.iloc[:,1]

# %%
#Plot Data Set

sns.set_style('darkgrid')
plt.scatter(x,y)
plt.title('Scatter plot of Swedish Insurance Data')
plt.xlabel('Number of Claims')
plt.ylabel('Total Amount of Claims (thousands)')
plt.show()

# %%
#Transform data into input for model

x = pd.DataFrame(x)
y = pd.Series(y)

# %%
# Create linear regression object
reg_model = LinearRegression()

# Fit the model to the data
reg_model.fit(x,y)

# Get the coeffients, intercept, R^2

beta = reg_model.coef_
intercept = reg_model.intercept_
R_squared = reg_model.score(x,y)

print("beta = ", beta)
print("intercept = ", intercept )
print("R_squared = ", R_squared)
# Out:
# beta =  [3.41382356]
# intercept =  19.994485759114795
# R_squared =  0.8333466719794502

# %%
# plot data with regression line
plt.scatter(x, y)
plt.plot(x, reg_model.predict(x), color = 'black')
plt.title('Linear Regression Swedish Insurance Data')
plt.xlabel('Number of Claims')
plt.ylabel('Total Amount of Claims (thousands)')
plt.show()

# %%
df = df[df!=0]
df['avgclaim'] = df['y'] / df['x']
df = df.dropna()
df.head()
# Out:
#        x      y  avgclaim
# 0  108.0  392.5  3.634259
# 1   19.0   46.2  2.431579
# 2   13.0   15.7  1.207692
# 3  124.0  422.2  3.404839
# 4   40.0  119.4  2.985000

# %%
plt.hist(df['avgclaim'])
plt.title('Average Claim Amount By Region')
plt.xlabel('Frequency')
plt.ylabel('Average Claim Amount')
plt.show()
